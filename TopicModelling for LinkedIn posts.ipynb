# %% [markdown]
# # Импорт библиотек и загрузка данных

# %%
! pip install spacy
! python -m spacy download ru_core_news_sm
! python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\user\anaconda3\lib\site-packages (3.5.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.23.5)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (0.10.2)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from spacy) (63.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.10.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\user\anaconda3\lib\site-packages (from spacy) (8.1.10)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\user\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)
# Collecting ru-core-news-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.5.0/ru_core_news_sm-3.5.0-py3-none-any.whl (15.3 MB)
#      ---------------------------------------- 15.3/15.3 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: pymorphy3>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from ru-core-news-sm==3.5.0) (1.2.0)
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from ru-core-news-sm==3.5.0) (3.5.4)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\users\user\anaconda3\lib\site-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.5.0) (0.7.2)
# Requirement already satisfied: docopt>=0.6 in c:\users\user\anaconda3\lib\site-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.5.0) (0.6.2)
# Requirement already satisfied: pymorphy3-dicts-ru in c:\users\user\anaconda3\lib\site-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.5.0) (2.4.417150.4580142)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.0.4)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (63.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.28.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (5.2.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (8.1.10)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (21.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.0.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.8)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.10.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.10.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.3.0)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.9.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.23.5)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.12)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.26.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.7.9)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 12.8/12.8 MB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from en-core-web-sm==3.5.0) (3.5.4)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (63.4.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (5.2.1)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.23.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.64.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.2)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (21.3)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.10)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.28.1)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
pip install langdetect
# Out:
# Requirement already satisfied: langdetect in c:\users\user\anaconda3\lib\site-packages (1.0.9)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from langdetect) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from collections import Counter
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from string import punctuation
import spacy
from langdetect import detect

# %%
file_path = 'post_users_links.csv'

# %%
data = pd.read_csv(file_path)

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# # Определение языковых моделей

# %%
nlp_eng = spacy.load('en_core_web_sm', disable=['ner', 'parser'])
nlp_rus = spacy.load('ru_core_news_sm', disable=['ner', 'parser'])

stop_words_rus = set(stopwords.words('russian'))
stop_words_eng = set(stopwords.words('english'))
stop_words = stop_words_rus.union(stop_words_eng)

words_to_exclude = set(punctuation)

# %% [markdown]
# # Очистка и лемматизация постов

# %%
filtered_data = data.copy()

selected_posts = []
all_sentences = []

for index in range(len(filtered_data["posts"])):
    value = filtered_data.loc[index, "posts"]
    try:
        lang = detect(value)

        if lang == 'en':
            doc = nlp_eng(value)
            lemmas = [token.lemma_ for token in doc if token.is_alpha and token.text not in punctuation]
            cleaned_sentence = ' '.join(lemmas)
            all_sentences.append(cleaned_sentence)
            filtered_data.loc[index, 'selected_posts'] = cleaned_sentence
        elif lang == 'ru':
            doc = nlp_rus(value)
            lemmas = [token.lemma_ for token in doc if token.is_alpha and token.text not in punctuation]
            cleaned_sentence = ' '.join(lemmas)
            all_sentences.append(cleaned_sentence)
            filtered_data.loc[index, 'selected_posts'] = cleaned_sentence
        else:
            filtered_data.loc[index, 'selected_posts'] = np.nan
    except Exception as e:
        print(f"Error processing value: {value}")
        print(f"Error message: {str(e)}")
        
filtered_data = filtered_data.dropna(subset=['selected_posts'])

print(len(all_sentences))
print(filtered_data.shape)
# Out:
# Error processing value: https://lnkd.in/g2ryPnc
# Error message: No features in text.
# Error processing value: https://lnkd.in/gkvaEp44
# Error message: No features in text.
# Error processing value: https://lnkd.in/eS3FUqh
#
# https://lnkd.in/evtby-E
# Error message: No features in text.
# Error processing value: +
# Error message: No features in text.
# Error processing value: 👍🏽👍🏽
# Error message: No features in text.
# Error processing value: 😞
# Error message: No features in text.
# Error processing value: ❤️
# Error message: No features in text.
# Error processing value: https://lnkd.in/fkXPmBu
# Error message: No features in text.
# Error processing value: 😁
# Error message: No features in text.
# Error processing value: https://t.co/0NXqsMK256
# Error message: No features in text.
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# Error processing value: nan
# Error message: expected string or bytes-like object
# 1226
# (1226, 9)

# %% [markdown]
# # Векторизация текстов и LDA

# %%
tfidf = TfidfVectorizer(stop_words=stop_words, min_df=4, max_df=0.95)

# %%
x = tfidf.fit_transform(all_sentences)

# %%
id2word = {i: token for i, token in enumerate(tfidf.get_feature_names())}
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
n_topics=15

# %%
lda = LatentDirichletAllocation(n_components=n_topics, random_state=12345)

# %%
topics = lda.fit_transform(x)

# %%
main_topics = pd.DataFrame()

# %% [markdown]
# Посмотрим на ключевые слова тем

# %%
for i in range(n_topics):
    c = lda.components_[i, :]
    topic_tokens = [id2word.get(token_id) for token_id in np.argsort(c)[-20:]]
    print("Тема",i+1, ":")
    main_topics.loc[i,'Тема'] = i+1
    print(", ".join(topic_tokens))
    main_topics.loc[i,'Ключевые слова'] = ", ".join(topic_tokens)
    print("\n ")
# Out:
# Тема 1 :
# institute, contact, build, strategy, view, verified, complete, obtain, achievement, initiative, cost, finance, tableau, certification, want, start, position, new, share, happy
#
#
# Тема 2 :
# система, post, облачный, аналитик, online, russian, бесплатный, neuralnetwork, experience, сервис, курс, method, open, первый, английский, время, ai, article, новый, год
#
#
# Тема 3 :
# программист, ссылка, programming, machine, language, сайт, python, dataengineere, always, datascience, sql, hr, вакансия, dataanalytic, see, linkedinskillassessment, skill, next, earn, badge
#
#
# Тема 4 :
# money, компания, much, one, life, country, поддерживать, nice, сообщать, great, начинать, university, deliver, новый, должность, junior, blockchain, good, удовольствие, developer
#
#
# Тема 5 :
# база, данных, software, всем, cloudcompute, веб, управление, компания, linkedin, openforbusiness, услуги, просмотреть, оказывать, радость, сообщать, страница, приложение, услуга, бизнес, разработка
#
#
# Тема 6 :
# leader, healthcare, пользоваться, opentowork, мочь, здравствовать, новый, рекомендация, предложить, ваш, поиск, благодарить, карьерный, заранее, которые, контакт, поддержка, совет, весь, возможность
#
#
# Тема 7 :
# хороший, наш, кандидат, filimonova, video, искать, react, udemy, redux, ci, казахстан, friend, backend, frontend, работа, product, manager, задача, опыт, команда
#
#
# Тема 8 :
# anyone, article, alexander, like, well, дело, colleague, alone, break, text, language, dynamic, valuable, must, architect, deal, хороший, google, highly, recommend
#
#
# Тема 9 :
# работать, знание, информация, data, спасибо, опыт, человек, sql, весь, дизайн, друг, делать, react, свой, проект, благодарность, интересный, отзыв, это, работа
#
#
# Тема 10 :
# power, explanation, ever, understand, non, security, moscow, hierarchical, one, study, экономика, case, game, model, crypto, thing, smart, joke, different, ukraine
#
#
# Тема 11 :
# tech, show, market, share, get, one, company, go, come, ready, startup, time, take, like, ai, work, datum, make, use, product
#
#
# Тема 12 :
# creative, lookingforjob, полезный, cv, job, new, everyone, offer, role, would, support, thank, advice, look, connection, advance, appreciate, hi, opentowork, opportunity
#
#
# Тема 13 :
# relevant, post, network, project, conference, remote, day, quote, webdesign, understand, team, stop, app, ux, hey, think, work, code, design, ui
#
#
# Тема 14 :
# skill, excited, application, year, software, provide, announce, linkedin, page, web, experience, design, check, management, business, project, service, development, finish, course
#
#
# Тема 15 :
# fintech, tbilisi, georgia, engineering, editor, linkedinskillassessment, тест, проверка, значок, science, следующий, пройти, well, хотеть, навык, know, interested, might, anyone, hire

# %% [markdown]
# Посмотрим на типичные посты в каждом топике

# %%
for i in range(n_topics):
    doc_id = np.argmax(topics[:, i])
    print(doc_id)
    print("Тема ", i+1)
    print(filtered_data.iloc[doc_id]["posts"])
    main_topics.loc[i,'Типичный пост'] = filtered_data.iloc[doc_id]["posts"]
    print("\n")
# Out:
# 522
# Тема  1
# It’s been a while since I’ve completed my program at Bauman Moscow State Technical University, but I wanted to share this update with everyone.
#
#
# 1138
# Тема  2
# So I published my first article on arXiv https://lnkd.in/gfr6cuy!!! The article is about a new method for choosing the optimal learning neural network. From this method, the creation of a meta-learning algorithm follows! Be free to ask questions. I am open to discussing the article.#datascience #deeplearning #neuralnetwork #ai
#
#
# 574
# Тема  3
# I just earned a skill badge for MySQL! Who's next? See how you do on a #LinkedInSkillAssessment. #sql #sqlserver #sqlprogramming #dataengineering #dataanalytics #datascience #etl #datapipelines
#
#
# 1020
# Тема  4
# 🚀 We just launched a six-week BNBChain Zero2Hero Bootcamp program for the Russian cohort, and it's off to a great start. Out of 642 applicants, we chose the best 200 individuals to receive expert training and mentorship from industry leaders in blockchain technology.                The bootcamp runs from March 6 to April 14 and covers blockchain technology concepts from the ground up. Participants will collaborate on a final blockchain project and earn an NFT certificate upon completion. 🔥                                   The Blockchain Center is committed to providing continuous support to these developers throughout their journey and is eager to witness their future contributions.📌 As a note: BNBChain Zero2Hero Builders Series, a six-month online program for developers of all levels, including a four-week hackathon and six-week incubator training.#technology #future #leaders #blockchain #bootcamp
#
#
# 898
# Тема  5
# С радостью сообщаю, что я оказываю бизнес-услуги в LinkedIn #OpenForBusiness. Просмотрите мою страницу услуг «Составление технической документации, Ведение переговоров, Формирование команды, Управление проектами, Управление программами, Интернет-исследование, Создание презентаций, Обучение, Проверка резюме» и «Публичное выступление».
#
#
# 160
# Тема  6
# In a survey of 2,500 business leaders around the world, only half said their organizations are prepared for the future. How can leaders reorient their organizations to chart a path through change and seize new growth opportunities? The State of Organizations report dives into the 10 most important shifts businesses are grappling with—and what leaders and their teams can do about them. Explore them below and more in depth here: https://mck.co/StateOfOrgs
#
#
# 376
# Тема  7
# Необходим Backend developer PHP Junior / MiddleТребования к кандидату: Опыт PHP 7+ OOPLaravel (плюсом будет опыт работы с Yii2)MySQL, MongoDB, RedisGITОпыт написания REST APIПлюсом будет:Опыт работы с docker, навыки администрирования LinuxКомпания предлагает: Гибкий графикВозможность работы удаленноДостойная оплата труда от 500 до 3000 бел рублей (по результатам собеседования)Интересные задачи в продуктовой компании #php #laravel #mysql #mongoDB #Redis #Yii2 #GITРезюме присылать на электронный адрес admin@dumki.by
#
#
# 599
# Тема  8
# Brotli is Google's compression algorithm. Significantly reduces the size of text files (HTML, CSS, JavaScript) when transferred between the server and browser.Brotli, provides better compression results than Gzip. Compressing resources minimizes size, and therefore reduces download times and hence the LCP (download speed of the underlying content).Unfortunately, Brotli is not part of the default NGINX package at this time, so you have to load it as a dynamic or static module. NGINX Plus has official support for the Brotli module. And all you have to do is just apt-get install and that's it 😀.I don't have it, so we go another way: https://lnkd.in/gnT5EQ93#nginx #brotli #lcp
#
#
# 1053
# Тема  9
# Последние лет 10 тема мотивации бьет изо всех щелей: награждай себя за полезное действие. Научись понимать выгоду, от того, что не тупил в Доту или сериал, а продуктивно провёл день. Всем так хочется научиться обманывать лень, что слово "надо" оказалось забытым. Проблема мотивации в том, что она приходит и уходит: после "неправильного" разговора с заказчиком. В случае появления нового параллельного проекта. При каких-то жизненных обстоятельствах. И если ты не можешь поднять себя с дивана через нехочу - на мой взгляд, это большая проблема. В долгосрочном плане, важно не горение "неделю или месяц" новым проектом, а умение планомерно что-то делать в любом психологическом состоянии
#
#
# 587
# Тема  10
# Do not miss the 3d session of the State of Bayes webinar from PyMC Labs tonight. I will talk and answer questions about hierarchies, where they come from and how to move from a non-hierarchical model to a hierarchical one. We will also learn how to effectively use prior predictive to debug a model.If you have not registered yet, here is the link to the event
#
#
# 164
# Тема  11
# The idea of emergent behavior can explain why ChatGPT and its successors like GPT-X may give rise to artificial general intelligence.Emergent behavior occurs when a new, often unexpected, behavior emerges from a system - one that could not have been predicted if one were just evaluating each of the system's constituent behaviors.A good example is the emergence of life.A cell is composed of organelles with specialized functions - functions that would not lead any independent observation to deduce that the interactions between these functions would emerge the process of life.Likewise, ChatGPT is built on independent constituents like foundation models, transformers, and reinforcement learning with human feedback.What we are starting to see with GPT-4 is the emergence of human-level intelligence:1️⃣ Reasoning2️⃣ Problem Solving3️⃣ Abstract Thinking4️⃣ Comprehension of Complex Ideas5️⃣ Fast Learning and Learning from ExperienceAlthough we have yet to see true planning emerge, it is only a matter of time before these models reach that level.. . .#ai #ml #generativeai #chatgpt #gpt4
#
#
# 398
# Тема  12
# That's how I crossed Russia - Georgia border after recent news in Russia 🥲 I'm in Tbilisi now 📍BTW I looking for a Frontend job (middle+/senior), please share this post, it might help to find a job. Peace to the world, let it rotate (c) ☮️ 🌎#frontend #share #help #reactjs #react #refugees #lookingforjob #lookingforopportunities #lookingforajob #javascriptdeveloper #javascriptengineer #javascript #peace
#
#
# 1214
# Тема  13
# Hi network. It's almost first Advent, which means that it's time to circulate the #yearly #communitydriven #survey we distribute among #IT professionals in #Germany. Please contribute by anonymously filling the form and sharing this post. Link to the form: https://lnkd.in/dYRurmuThis year's edition also includes #covid19 related questions to see how our peers were affected by the pandemic related crisis.The results shall be published around XMas'20. The prev. year's results can be found here: https://lnkd.in/dbiWypdI tag you guys for reachability if you don't mind :)Elena Paula Helen Inna Dat Andreas Tarry Alexey Anthony Luke #engineering #software #datascience #dataengineering #statistics #jobmarket #salary
#
#
# 77
# Тема  14
# Thinking about my career in IT 😏 Sounds crazy. But I wrote the first program 16 years ago when I was 12. I started, like everyone else, with BASIC. Then I got interested in C++. My first operating system was Windows XP.  Even somewhere at home there is a diploma about taking a place in the competition with the "Win32 API" project. Yes, in the 6th grade of school I was fond of such things.My first project for the Young Talent Competition was a C++ application. Using the Windows API, I loaded my library into the address space of the Explorer process.  And accidentally moved the Start button in Windows XP every time the user hovered over the mouse 😄It was a school project, but then it was cool. #project #school #firstproject #talent #winapi
#
#
# 396
# Тема  15
# 📢 Do you miss talking to colleagues and like-minded people from the global dev community?Let’s meet next week and enjoy an intellectual engineering atmosphere in Tbilisi, Georgia. 🇬🇪✍️ Register today and join Evolution Tech #Meetup for free on October 13th!More details and registration:OFFLINE in Tbilisi (Georgia) ➡️ https://lnkd.in/dFQ-NygcONLINE ➡️ https://lnkd.in/d_STSBuzMeet you there!#techmeetup #evolution #engineering

# %%
topic_assignments = lda.transform(x)
filtered_data['topic'] = np.argmax(topic_assignments[:len(filtered_data)], axis=1) % n_topics + 1

# %%
filtered_data['reactions'] = pd.to_numeric(filtered_data['reactions'], errors='coerce')
top_topics = filtered_data.groupby('topic').agg({'reactions': 'sum'}).nlargest(10, 'reactions').index
filtered_data['top10topics'] = np.where(filtered_data['topic'].isin(top_topics), 'top10', '')
filtered_data['topic_reactions'] = filtered_data.groupby('topic')['reactions'].transform('sum')

# %%
filtered_data = filtered_data.reset_index()
display(filtered_data.head(15))
# Out:
#     index  Unnamed: 0            name  \
# 0       0           0  ARTEM DOROFEEV
# 1       1           1  Aida Borlakova
# 2       2           2  Aida Borlakova
# 3       3           3  Aida Borlakova
# 4       4           4  Aida Borlakova
# 5       5           5  Aida Borlakova
# 6       6           6  Aida Borlakova
# 7       8           8  Aida Borlakova
# 8       9           9  Aida Borlakova
# 9      10          10  Aida Borlakova
# 10     11          11  Aida Borlakova
# 11     12          12  Aida Borlakova
# 12     13          13  Aida Borlakova
# 13     14          14  Aida Borlakova
# 14     15          15  Aida Borlakova
#
#                                              works_at  \
# 0   Backend senior software developer at Kaspersky...
# 1           Global IT Talent Scout |Team4You |10 000+
# 2           Global IT Talent Scout |Team4You |10 000+
# 3           Global IT Talent Scout |Team4You |10 000+
# 4           Global IT Talent Scout |Team4You |10 000+
# 5           Global IT Talent Scout |Team4You |10 000+
# 6           Global IT Talent Scout |Team4You |10 000+
# 7           Global IT Talent Scout |Team4You |10 000+
# 8           Global IT Talent Scout |Team4You |10 000+
# 9           Global IT Talent Scout |Team4You |10 000+
# 10          Global IT Talent Scout |Team4You |10 000+
# 11          Global IT Talent Scout |Team4You |10 000+
# 12          Global IT Talent Scout |Team4You |10 000+
# 13          Global IT Talent Scout |Team4You |10 000+
# 14          Global IT Talent Scout |Team4You |10 000+
#
#                                                 posts  reactions  \
# 0                                         #OpenToWork        0.0
# 1   #humour Переквалифицировался, прошел курсы IT ...        7.0
# 2   #google #pandas #вакансия #аналитик #TeamLead ...        4.0
# 3   Вакансия #SolutionArchitect Проекты: 1. Интегр...        9.0
# 4   Кто накидает мне здесь контакты аутстафф компа...        1.0
# 5   🔍 DevOps engineer, грейд middleРазработка Data...        1.0
# 6   Системный аналитик(Data/ETL)💼 Проект: разработ...        2.0
# 7   #python #django #remote 📣 Друзья, порекомендуй...        8.0
# 8   #referal #senior #java #hrЕсть сильный бекенд ...        7.0
# 9   I’m #hiring. Know anyone who might be interested?        2.0
# 10  #вакансия #cистемныйаналитик💻 Проект: разработ...       10.0
# 11  #sales #рекомендация #businessdevelopmentmanag...        7.0
# 12  SEO manager Удалённый формат из любой точки ми...        2.0
# 13  I’m #hiring. Know anyone who might be interested?        6.0
# 14  I’m #hiring. Know anyone who might be interested?        3.0
#
#                                      current_position ttl_duration  \
# 0   Backend senior software developer at Kaspersky...    3561 days
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7                                                 NaN          NaN
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 10                                                NaN          NaN
# 11                                                NaN          NaN
# 12                                                NaN          NaN
# 13                                                NaN          NaN
# 14                                                NaN          NaN
#
#                                    link  \
# 0   https://www.linkedin.com/in/eocron/
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
#
#                                        selected_posts  topic top10topics  \
# 0                                          opentowork     12       top10
# 1   humour переквалифицироваться пройти курс it пр...      2       top10
# 2   google pandas вакансия аналитик teamlead remot...      7       top10
# 3   вакансия solutionarchitect проект интеграционн...     13
# 4   кто накидает мне здесь контакт аутстафф компан...      6
# 5   devops engineer грейд middleразработка dataops...      7       top10
# 6   системный etl проект разработка система по кли...      7       top10
# 7   python django remote друг порекомендуйте пожал...      3       top10
# 8   referal senior java hrЕсть сильный бекенд прог...      3       top10
# 9          I hire know anyone who might be interested     15
# 10  вакансия cистемныйаналитика проект разработка ...      5       top10
# 11  sales рекомендация businessdevelopmentmanager ...      2       top10
# 12  seo manager удалённый формат из любой точка ми...      3       top10
# 13         I hire know anyone who might be interested     15
# 14         I hire know anyone who might be interested     15
#
#     topic_reactions
# 0            1247.0
# 1            2989.0
# 2            2243.0
# 3             769.0
# 4             526.0
# 5            2243.0
# 6            2243.0
# 7             808.0
# 8             808.0
# 9             457.0
# 10           1110.0
# 11           2989.0
# 12            808.0
# 13            457.0
# 14            457.0

# %% [markdown]
# # Повторение операций для постов, связанных с менторингом

# %%
mentoring_list_lemmas_eng = [
    'mentoring',
    'mentorship',
    'mentor',
    'onboarding',
    'coach',
    'coaching',
    'adaptation',
    'advise',
    'intern',
    'onboarding',
    'adaptation',
    'adviser',
    'coach',
    'mentor',
    'mentorship',
    'teach',
    'tutor'
]

mentoring_list_lemmas_rus = [
    'взять',
    'готовый',
    'готов',
    'менторство',
    'начинать',
    'прокачать',
    'прокачаться',
    'развивайся',
    'развиваться',
    'совет',
    'ученик',
    'научить',
    'научиться',
    'менторство',
    'менторинг',
    'наставничество',
    'ментор',
    'наставник',
    'наставлять'
    'онбординг',
    'адаптация',
    'коучинг',
    'коуч',
    'менторить',
    'наставлять'
]

# %%
mentoring_data = filtered_data.copy()

all_sentences_mentoring = []

for index in range(len(mentoring_data["posts"])):
    value = mentoring_data.loc[index, "posts"]
    try:
        lang = detect(value)

        if lang == 'en':
            doc = nlp_eng(value)
            lemmas = [token.lemma_ for token in doc if token.is_alpha]
            if any(lemma in mentoring_list_lemmas_eng for lemma in lemmas):
                cleaned_sentence = ' '.join(lemmas)
                if cleaned_sentence:
                    all_sentences_mentoring.append(cleaned_sentence)
                    mentoring_data.loc[index, 'selected_posts_mentoring'] = cleaned_sentence
        elif lang == 'ru':
            doc = nlp_rus(value)
            lemmas = [token.lemma_ for token in doc if token.is_alpha]
            if any(lemma in mentoring_list_lemmas_rus for lemma in lemmas):
                cleaned_sentence = ' '.join(lemmas)
                if cleaned_sentence:
                    all_sentences_mentoring.append(cleaned_sentence)
                    mentoring_data.loc[index, 'selected_posts_mentoring'] = cleaned_sentence
        else:
            mentoring_data.loc[index, 'selected_posts_mentoring'] = np.nan
    except Exception as e:
        print(f"Error processing value: {value}")
        print(f"Error message: {str(e)}")

mentoring_data = mentoring_data.dropna(subset=['selected_posts_mentoring'])

print(len(all_sentences_mentoring))
print(mentoring_data.shape)
# Out:
# 91
# (91, 14)

# %%
x = tfidf.fit_transform(all_sentences_mentoring)

# %%
id2word = {i: token for i, token in enumerate(tfidf.get_feature_names())}
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
n_topics=10

# %%
lda = LatentDirichletAllocation(n_components=n_topics, random_state=12345)

# %%
topics_mentoring = lda.fit_transform(x)

# %%
mentoring_topics = pd.DataFrame()

# %%
for i in range(n_topics):
    c = lda.components_[i, :]
    topic_tokens = [id2word.get(token_id) for token_id in np.argsort(c)[-20:]]
    print("Тема",i+1, ":")
    mentoring_topics.loc[i,'Тема'] = i+1
    print(", ".join(topic_tokens))
    mentoring_topics.loc[i,'Ключевые слова'] = ", ".join(topic_tokens)
    print("\n ")
# Out:
# Тема 1 :
# experience, направление, manager, work, share, product, second, use, полный, startup, coach, country, one, training, teach, think, make, new, управление, business
#
#
# Тема 2 :
# may, start, coach, job, country, development, etc, provide, good, receive, mentorship, great, специалист, look, engineer, use, experience, data, python, developer
#
#
# Тема 3 :
# want, experience, startup, любой, teach, good, learn, run, работать, need, важный, like, work, start, опыт, технический, технология, оборудование, начинать, хороший
#
#
# Тема 4 :
# оборудование, time, начинать, условие, основный, управление, javascript, привет, всем, направление, разный, работа, искать, информация, нужный, весь, умение, developer, frontend, человек
#
#
# Тема 5 :
# мочь, ux, follow, problem, продукт, готовый, ссылка, уровень, делать, результат, свой, ui, курс, проект, задача, компания, опыт, работа, команда, это
#
#
# Тема 6 :
# сообщать, удовольствие, blockchain, весь, мочь, поиск, здравствовать, opentowork, рекомендация, совет, предложить, карьерный, которые, благодарить, контакт, поддержка, заранее, ваш, новый, возможность
#
#
# Тема 7 :
# подготовка, полезный, человек, следующий, начинать, основный, совет, great, go, development, это, coach, think, канал, больший, специалист, условие, tool, резюме, вакансия
#
#
# Тема 8 :
# share, course, курс, возможность, разный, информация, work, вакансия, well, tool, one, ваш, работа, may, развивать, полный, second, job, experience, teach
#
#
# Тема 9 :
# работать, решение, разработчик, приложение, удалённый, других, вопрос, умение, совет, frontend, look, opportunity, вакансия, api, требоваться, дальнейший, css, полный, писать, английский
#
#
# Тема 10 :
# take, business, look, coach, university, time, job, etc, opportunity, make, experience, well, many, startup, problem, teach, stay, new, get, use

# %%
for i in range(n_topics):
    doc_id = np.argmax(topics_mentoring[:, i])
    print(doc_id)
    print("Тема ", i+1)
    print(mentoring_data.iloc[doc_id]["posts"])
    mentoring_topics.loc[i,'Типичный пост'] = mentoring_data.iloc[doc_id]["posts"]
    print("\n")
# Out:
# 15
# Тема  1
# Have you heard of the Nail Polish Effect?Originally known as the “Lipstick Effect,” it was coined by Leonard Lauder - heir to The Estée Lauder Companies Inc.The Nail Polish Effect is the observation that affordable luxury products and services have historically been able to withstand a recession.This has been true for every major U.S. recession dating back to the 70s.In 2008, when real estate and banking institutions took a huge hit, the nail business was still growing as consumer demand actually picked up.Within the global beauty and personal care industry, economic data shows that nail polish is the fastest-growing category.Okay, why does this matter?. . . I just wanted to share my experience investing in small businesses with other small business owners.It took me a few years to hone in on the nail salon industry, and I want to share the mistakes I made so others can avoid them.I made the jump almost 2 years ago - it was tough for sure given COVID-19, but business boomed as the restrictions started lifting off.There was no profit the first year, but for our full 2nd year in business, I am happy and grateful to share that we made enough to cover my initial cost.That’s a pretty healthy multiple in 2 years and the business is cashflow positive now.So how did I make nails work?. . .First, I am grateful I had a mentor who had 20 years of experience managing a “nail empire” on the East Coast.He told me that my real customers were my employees - staff retention is the biggest hurdle you must solve in this industry.The second biggest challenge was marketing - I was able to transfer my “tech startup mindset” and built a loyalty program that gamified the nail experience for our customers.Also, just like in real estate.Location, location, location.Make sure you know your “ideal client profile” or ICP and treat them well.And make sure your location aligns with attracting that ICP.. . .Sorry, this has been a bit of a jumbled collection of thoughts about the nail salon business.I hope you have found it somewhat helpful if you're thinking about a real asset diversifying investment outside of real estate.If you’re in nails or beauty, please don’t hesitate to reach out for a quick intro - always happy to network.-Andy. . .#nailsalon #nails #nailtech #beauty #cosmetology #startups #businessowners #smallbusinesses
#
#
# 79
# Тема  2
# Дополните вашу команду нашими специалистами. Мы открыты к различным предложениям и работе как в формате аутсорсинга, так и аутстаффинга. В данный момент у нас готовы к тому, чтобы внести ценность в ваш проект следующие специалисты:	⁃	Data Engineer | Python, Docker, SQL, etc. 4+ years of experience 	⁃	Data Scientist | Python, SQL, NLP, ML 3+ years of experience 	⁃	UX/UI designer | Figma, Adobe XD 2+ years of experience 	⁃	Front-end developer | JavaScript, React, SQL 5+ years of experience Для более подробной информации о незанятых специалистах из списка обращайтесь любым удобным образом:Email: sales@datalize.org TG: @StVladislav #python #data #outstaffing #outsourcing
#
#
# 27
# Тема  3
# Hey friends,I’m excited to share some news that’s close to my heart. I’m getting back in the swing of things, starting a new venture called CanFY, a neat project that works on AI assistance for developer tools. It’s time to clear the fog of mystery - I’m stepping up as the Co-founder and CEO.  Feels good to be back at the helm!My previous experience as a co-founder has always been rewarding and I’ve carried those lessons with me while counseling other growth-stage startups for several years. I’ve been looking out for something that really spoke to me, something worth investing my energy and time in. When I stumbled upon the idea for CanFY, it was as if everything clicked into place.What makes it even better? My partner Alex Gaziev and I are joining forces with the fantastic team from Evil Martians. They’re some of the best in the startup development and devtools world, and their support and advice are invaluable.I’ve always enjoyed being part of the startup world - the energy, the challenges, the late-night brainstorming sessions - they all add up to a thrilling experience. But this time, with CanFY, it’s different. It feels like we’re on the cusp of something truly great. The market’s ready for a new player, and our team is raring to go. We’re not just hoping for the best, we’re working towards creating something that’s going to make a real difference.So there you have it, folks! I’m jumping back into the driver’s seat with CanFY and couldn’t be more excited. I can’t wait to share more of our journey with you - stay tuned, and I’m open to conversations in DM!Thanks to all of my early mentors who navigated me through the peculiarities of startups - Or Haviv Jan Jedlinski Wendy van Leeuwen and Booking.com Booster Labs team. It was truly a pleasure to learn from your lessons.#AI #startups #newbeginnings #entrepreneurship #CanFY
#
#
# 46
# Тема  4
# Надеюсь на силу LinkdIna 🙏Очень прекрасный человек ищет работу на позицию Junior IOS Developer.Если вам нужен человек, который горит делом всем сердцем и поглощает информацию, как губка, то пишите https://lnkd.in/gA7A6q3HПожалуйста, репостните, все мы начинали Джунами 🧐
#
#
# 56
# Тема  5
# What is the main reason for failure to crack interviews? Let me tell you -..It is inconsistency in problem-solving, especially when it comes to DSA many aspirants do not practice the amount they should. While every aspirant learns at their own pace, it is really important to keep making progress, however small it may be. But when you have a structured resource to practice from, I think it becomes easier to be consistent →I’m sharing this DSA practice doc (it’s interactive as well) that may help you master problem-solving. Credit goes to Bosscoder Academy, which has helped 400+ aspirants crack their dream tech roles.How? By providing - ✅ Live classes taken by MAANG Software Engineers✅ 1:1 mentorship to every aspirant✅ 24 X 7 Doubt Support✅ Placement assistance (with possible referrals to aspirants)You can check them out here: https://bit.ly/3I39ib5Check the comment for more details.Follow Aman Barnwal for more.  #learning #dsa #google #datastructures #algorithms #cse #jobs #interviews #placements #google #amazon #tech #interview #placements #techjobs #codinginterview #programming #careers #resourcesharing #github #amantalks
#
#
# 69
# Тема  6
# I am thrilled to share my incredible experience teaching over 300 teachers from 22 universities at University Outreach Program in Blockchain Center. In collaboration with the Binance Academy, Astana Hub, and the National payment corporation of Kazakhstan, we conducted comprehensive courses on blockchain engineering and compliance. The graduation ceremony went at the decentral.asia Forum.It is with great pride that I announce the successful completion of these courses by the participating teachers, who have earned well-deserved certificates of completion. Their dedication to enhancing their knowledge and skills in blockchain technology is truly inspiring. During the forum, we also witnessed the outstanding talent displayed at the Decentrathon, Central Asia's largest blockchain hackathon. Congratulations to all the winners!The discussions surrounding the digital tenge and cryptocurrencies were particularly enlightening. As we navigate the ever-evolving landscape of digital currencies, it is essential for educators to understand the potential implications and equip students with the necessary knowledge for this exciting frontier.I am grateful to have been part of this collaborative effort and would like to extend my heartfelt appreciation to the Blockchain Center, Binance Academy, Astana Hub, and the National payment corporation of Kazakhstan for their invaluable support in promoting blockchain education. Additionally, I want to express my appreciation for individuals like Aidana Kaskyrbek, Aigerim Gilmanova, Arailym Kozhanova, Dosymzhan Begaidarov, Alnur Karabayev, Meruyert Tleubergenova, Laura Nurmaganbetova, Aisulu Rakhimbekova, Collectively, we are making significant inroads in shaping the future of blockchain technology in our local environs. I eagerly anticipate the emergence of further collaborative gateway and platforms to further augment the ecosystem's growth and sustainability.#BlockchainEducation #DecentralAsiaForum #Decentrathon #DigitalTenge #Cryptocurrencies #Collaboration
#
#
# 58
# Тема  7
# !!! Отличная шпаргалка по основным IT словам и выражениям на английском языке с переводом на русский !!!Приглашаю вас подписаться на мой канал QA Life в телеграмме https://t.me/QA4Life. Это канал для начинающих и опытных тестировщиков, QA и QC, а также будет полезен также для PO, PM, DA, BA и SM специалистов Здесь я ежедневно делюсь ещё большим количеством материалов по тематике#IT #engineer #software #qa #qc #quality #recruiter #recruiting #HR #tester #qa_engineer #testing #PM #BA #DA #тестирование #development #developer #программирование #тестировщик #тестер #programming #development #mobileqa #mobiletesting
#
#
# 34
# Тема  8
# 𝙒𝙚 𝙡𝙚𝙖𝙧𝙣 ♡•10 percent of what we read,•20 percent of what we hear,•30 percent of what we see,•50 percent of what we see and hear,•70 percent of what we discuss,•80 percent of what we experience, and•95 percent of what we teach others.By William GlasserFollow Vikram Deo for more#storytelling #productivity #experience #jobs #india
#
#
# 81
# Тема  9
# Требуется PHP разработчик на проект, опыт от 3-х лет. Необходимо умение работать с REST API, MySQL, Фреймворк Yii2, HTML, CSS, JSЗадачи- Производить доработки существующего веб приложения, согласно составляемым техническим заданиям- Внедрение готовых решений Data Science, посредством REST API- Документирование внедренных изменений- Тестирование и отладкаУсловия- Возможен вариант удаленной работы- Гибкий график- Частичная или полная занятость- Своевременная оплата- Возможность в дальнейшем принимать участие в других проектахПо всем вопросам, прошу писать личное сообщение #Вебразработка #PHP #Frontend #Вакансии #IT
#
#
# 61
# Тема  10
# That's a time for a new job opportunity. I am looking for a company where I will stay for many years.I'm not ready for relocation by personal cause (I'm teach in the local university, organize a conference in Krasnodar, etc...). #OpenToWork

# %%
topic_assignments = lda.transform(x) 
mentoring_data['topic_mentoring'] = np.argmax(topic_assignments[:len(mentoring_data)], axis=1) % n_topics + 1

# %%
mentoring_data.loc[:, 'reactions'] = pd.to_numeric(mentoring_data['reactions'], errors='coerce')
mentoring_data['topic_mentoring_reactions'] = mentoring_data.groupby('topic_mentoring')['reactions'].transform('sum')

# %%
mentoring_data=mentoring_data.reset_index()
display(mentoring_data.head(15))
# Out:
#     level_0  index  Unnamed: 0                  name  \
# 0        15     16          16       Aigerim Mautkan
# 1        16     17          17       Aigerim Mautkan
# 2        18     19          19       Aigerim Mautkan
# 3        26     27          27     Aleksandr Drozdov
# 4        27     28          28     Aleksandr Drozdov
# 5        32     33          33     Aleksandr Drozdov
# 6        33     34          34     Aleksandr Drozdov
# 7        62     63          63     Aleksandra Belova
# 8        66     68          68               Alex Gr
# 9        70     72          72          Alex Tarasov
# 10       91     93          93    Alibek Nauryzbayev
# 11       92     94          94    Alibek Nauryzbayev
# 12       93     95          95         Alihan Urumov
# 13       94     96          96         Alihan Urumov
# 14      132    135         135  Andrew Steckley, PhD
#
#                                              works_at  \
# 0                                            AITAS KZ
# 1                                            AITAS KZ
# 2                                            AITAS KZ
# 3                   Senior Back End Software Engineer
# 4                   Senior Back End Software Engineer
# 5                   Senior Back End Software Engineer
# 6                   Senior Back End Software Engineer
# 7   BI Analytics | Team Lead | Data analysis | Vis...
# 8                                            Agile PM
# 9                            Full Stack Web Developer
# 10                                  Software engineer
# 11                                  Software engineer
# 12             IT Developer (Blockchain/Data science)
# 13             IT Developer (Blockchain/Data science)
# 14  Консультант, Главный специалист по данным, инж...
#
#                                                 posts  reactions  \
# 0   Здравствуйте, я в поиске новой карьерной возмо...        6.0
# 1   ПОЛЕЗНЫЙ СПИСОК ДЛЯ РЕКРУТЕРОВ И ТЕХ КТО В ПОИ...        NaN
# 2   ПОЛЕЗНЫЙ СПИСОК ДЛЯ РЕКРУТЕРОВ И ТЕХ КТО В ПОИ...        NaN
# 3   Здравствуйте, я в поиске новой карьерной возмо...        0.0
# 4   В с вязи с затруднениями в получении оборудова...        0.0
# 5   Здравствуйте, я в поиске новой карьерной возмо...        0.0
# 6   В с вязи с затруднениями в получении оборудова...        0.0
# 7   Why developing and business do not understand ...        2.0
# 8   Здравствуйте, я в поиске новой карьерной возмо...        5.0
# 9   Здравствуйте, я в поиске новой карьерной возмо...        1.0
# 10  Здравствуйте, я в поиске новой карьерной возмо...       23.0
# 11  С удовольствием сообщаю, что я начинаю работу ...       20.0
# 12  Здравствуйте, я в поиске новой карьерной возмо...        1.0
# 13  Здравствуйте, я в поиске новой карьерной возмо...        0.0
# 14  AI's Latest Snake Oil:New tools like GPTZero a...       16.0
#
#                      current_position ttl_duration  \
# 0                                 NaN          NaN
# 1                                 NaN          NaN
# 2                                 NaN          NaN
# 3   Senior Back End Software Engineer   10466 days
# 4   Senior Back End Software Engineer   10466 days
# 5   Senior Back End Software Engineer   10466 days
# 6   Senior Back End Software Engineer   10466 days
# 7                                 NaN          NaN
# 8                                 NaN          NaN
# 9            Full Stack Web Developer    4840 days
# 10                  Software engineer    9432 days
# 11                  Software engineer    9432 days
# 12                                NaN          NaN
# 13                                NaN          NaN
# 14                                NaN          NaN
#
#                                                  link  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3             https://www.linkedin.com/in/drozdosold/
# 4             https://www.linkedin.com/in/drozdosold/
# 5             https://www.linkedin.com/in/drozdosold/
# 6             https://www.linkedin.com/in/drozdosold/
# 7                                                 NaN
# 8                                                 NaN
# 9      https://www.linkedin.com/in/alex-tarasov-work/
# 10  https://www.linkedin.com/in/alibek-nauryzbayev...
# 11  https://www.linkedin.com/in/alibek-nauryzbayev...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                                        selected_posts  topic top10topics  \
# 0   здравствовать я в поиск новый карьерный возмож...      6
# 1   полезный список для рекрутеров и тех кто в пои...      3       top10
# 2   полезный список для рекрутеров и тех кто в пои...      3       top10
# 3   здравствовать я в поиск новый карьерный возмож...      6
# 4   в с вязь с затруднение в получение оборудовани...      1       top10
# 5   здравствовать я в поиск новый карьерный возмож...      6
# 6   в с вязь с затруднение в получение оборудовани...      1       top10
# 7   why develop and business do not understand eac...     14       top10
# 8   здравствовать я в поиск новый карьерный возмож...      6
# 9   здравствовать я в поиск новый карьерный возмож...      6
# 10  здравствовать я в поиск новый карьерный возмож...      6
# 11  с удовольствие сообщать что я начинать работа ...      4       top10
# 12  здравствовать я в поиск новый карьерный возмож...      6
# 13  здравствовать я в поиск новый карьерный возмож...      6
# 14  AI Latest Snake Oil new tool like GPTZero aim ...     11       top10
#
#     topic_reactions                           selected_posts_mentoring  \
# 0             526.0  здравствовать я в поиск новый карьерный возмож...
# 1             808.0  полезный список для рекрутеров и тех кто в пои...
# 2             808.0  полезный список для рекрутеров и тех кто в пои...
# 3             526.0  здравствовать я в поиск новый карьерный возмож...
# 4            2034.0  в с вязь с затруднение в получение оборудовани...
# 5             526.0  здравствовать я в поиск новый карьерный возмож...
# 6            2034.0  в с вязь с затруднение в получение оборудовани...
# 7            6726.0  why develop and business do not understand eac...
# 8             526.0  здравствовать я в поиск новый карьерный возмож...
# 9             526.0  здравствовать я в поиск новый карьерный возмож...
# 10            526.0  здравствовать я в поиск новый карьерный возмож...
# 11           1312.0  с удовольствие сообщать что я начинать работа ...
# 12            526.0  здравствовать я в поиск новый карьерный возмож...
# 13            526.0  здравствовать я в поиск новый карьерный возмож...
# 14           4751.0  AI Latest Snake Oil new tool like GPTZero aim ...
#
#     topic_mentoring  topic_mentoring_reactions
# 0                 6                      564.0
# 1                 7                      277.0
# 2                 7                      277.0
# 3                 6                      564.0
# 4                 3                      973.0
# 5                 6                      564.0
# 6                 3                      973.0
# 7                 5                      365.0
# 8                 6                      564.0
# 9                 6                      564.0
# 10                6                      564.0
# 11                6                      564.0
# 12                6                      564.0
# 13                6                      564.0
# 14                6                      564.0

# %%
mentoring_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   level_0                    91 non-null     int64
#  1   index                      91 non-null     int64
#  2   Unnamed: 0                 91 non-null     int64
#  3   name                       91 non-null     object
#  4   works_at                   91 non-null     object
#  5   posts                      91 non-null     object
#  6   reactions                  80 non-null     float64
#  7   current_position           23 non-null     object
#  8   ttl_duration               23 non-null     object
#  9   link                       23 non-null     object
#  10  selected_posts             91 non-null     object
#  11  topic                      91 non-null     int64
#  12  top10topics                91 non-null     object
#  13  topic_reactions            91 non-null     float64
#  14  selected_posts_mentoring   91 non-null     object
#  15  topic_mentoring            91 non-null     int64
#  16  topic_mentoring_reactions  91 non-null     float64
# dtypes: float64(3), int64(5), object(9)
# memory usage: 12.2+ KB

# %% [markdown]
# # Составление финального датасета и запись необходимых документов

# %% [markdown]
# Присоединяем к отфильтрованному датасету колонки из менторинга

# %%
final_data = filtered_data.merge(mentoring_data[['posts', 'topic_mentoring', 'topic_mentoring_reactions']], on='posts', how='left')
final_data = final_data.drop_duplicates()

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1226 entries, 0 to 1793
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      1226 non-null   int64
#  1   Unnamed: 0                 1226 non-null   int64
#  2   name                       1226 non-null   object
#  3   works_at                   1226 non-null   object
#  4   posts                      1226 non-null   object
#  5   reactions                  1166 non-null   float64
#  6   current_position           250 non-null    object
#  7   ttl_duration               250 non-null    object
#  8   link                       250 non-null    object
#  9   selected_posts             1226 non-null   object
#  10  topic                      1226 non-null   int64
#  11  top10topics                1226 non-null   object
#  12  topic_reactions            1226 non-null   float64
#  13  topic_mentoring            91 non-null     float64
#  14  topic_mentoring_reactions  91 non-null     float64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 153.2+ KB

# %% [markdown]
# Удаляем избыточные колонки

# %%
final_data = final_data.drop(columns=['index', 'Unnamed: 0', 'selected_posts'])

# %%
display(final_data.head(15))
# Out:
#               name                                           works_at  \
# 0   ARTEM DOROFEEV  Backend senior software developer at Kaspersky...
# 1   Aida Borlakova          Global IT Talent Scout |Team4You |10 000+
# 2   Aida Borlakova          Global IT Talent Scout |Team4You |10 000+
# 3   Aida Borlakova          Global IT Talent Scout |Team4You |10 000+
# 4   Aida Borlakova          Global IT Talent Scout |Team4You |10 000+
# 5   Aida Borlakova          Global IT Talent Scout |Team4You |10 000+
# 6   Aida Borlakova          Global IT Talent Scout |Team4You |10 000+
# 7   Aida Borlakova          Global IT Talent Scout |Team4You |10 000+
# 8   Aida Borlakova          Global IT Talent Scout |Team4You |10 000+
# 9   Aida Borlakova          Global IT Talent Scout |Team4You |10 000+
# 10  Aida Borlakova          Global IT Talent Scout |Team4You |10 000+
# 11  Aida Borlakova          Global IT Talent Scout |Team4You |10 000+
# 12  Aida Borlakova          Global IT Talent Scout |Team4You |10 000+
# 13  Aida Borlakova          Global IT Talent Scout |Team4You |10 000+
# 14  Aida Borlakova          Global IT Talent Scout |Team4You |10 000+
#
#                                                 posts  reactions  \
# 0                                         #OpenToWork        0.0
# 1   #humour Переквалифицировался, прошел курсы IT ...        7.0
# 2   #google #pandas #вакансия #аналитик #TeamLead ...        4.0
# 3   Вакансия #SolutionArchitect Проекты: 1. Интегр...        9.0
# 4   Кто накидает мне здесь контакты аутстафф компа...        1.0
# 5   🔍 DevOps engineer, грейд middleРазработка Data...        1.0
# 6   Системный аналитик(Data/ETL)💼 Проект: разработ...        2.0
# 7   #python #django #remote 📣 Друзья, порекомендуй...        8.0
# 8   #referal #senior #java #hrЕсть сильный бекенд ...        7.0
# 9   I’m #hiring. Know anyone who might be interested?        2.0
# 10  #вакансия #cистемныйаналитик💻 Проект: разработ...       10.0
# 11  #sales #рекомендация #businessdevelopmentmanag...        7.0
# 12  SEO manager Удалённый формат из любой точки ми...        2.0
# 13  I’m #hiring. Know anyone who might be interested?        6.0
# 14  I’m #hiring. Know anyone who might be interested?        3.0
#
#                                      current_position ttl_duration  \
# 0   Backend senior software developer at Kaspersky...    3561 days
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7                                                 NaN          NaN
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 10                                                NaN          NaN
# 11                                                NaN          NaN
# 12                                                NaN          NaN
# 13                                                NaN          NaN
# 14                                                NaN          NaN
#
#                                    link  topic top10topics  topic_reactions  \
# 0   https://www.linkedin.com/in/eocron/     12       top10           1247.0
# 1                                   NaN      2       top10           2989.0
# 2                                   NaN      7       top10           2243.0
# 3                                   NaN     13                        769.0
# 4                                   NaN      6                        526.0
# 5                                   NaN      7       top10           2243.0
# 6                                   NaN      7       top10           2243.0
# 7                                   NaN      3       top10            808.0
# 8                                   NaN      3       top10            808.0
# 9                                   NaN     15                        457.0
# 10                                  NaN      5       top10           1110.0
# 11                                  NaN      2       top10           2989.0
# 12                                  NaN      3       top10            808.0
# 13                                  NaN     15                        457.0
# 14                                  NaN     15                        457.0
#
#     topic_mentoring  topic_mentoring_reactions
# 0               NaN                        NaN
# 1               NaN                        NaN
# 2               NaN                        NaN
# 3               NaN                        NaN
# 4               NaN                        NaN
# 5               NaN                        NaN
# 6               NaN                        NaN
# 7               NaN                        NaN
# 8               NaN                        NaN
# 9               NaN                        NaN
# 10              NaN                        NaN
# 11              NaN                        NaN
# 12              NaN                        NaN
# 13              NaN                        NaN
# 14              NaN                        NaN

# %% [markdown]
# Сохраняем нужные файлы

# %%
main_topics.to_excel('main_topics.xlsx', index=False)
mentoring_topics.to_excel('mentoring_topics.xlsx', index=False)
final_data.to_excel('final_data.xlsx', index=False)
final_data.to_csv('final_data.csv', index=False)
